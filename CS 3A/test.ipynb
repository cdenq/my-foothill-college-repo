# %%
filename = "purple_air.csv"
import csv

# %%
with open(filename, "r") as file:
    csvreader = csv.reader(file)
    for i in csvreader:
        print(i)
# Out:
# ['Identifier', 'Approximate Zip Code', 'Reading Timestamp', 'Reading Day', 'Reading Time String', 'Concentration']
# ['Sensor 67357', '94028', '12/11/21 18:59:23', 'Saturday', 'Evening', '2.23']
# ['Sensor 67357', '94028', '12/12/21 00:59:27', 'Sunday', 'Night', '1.16']
# ['Sensor 67357', '94028', '12/12/21 06:59:31', 'Sunday', 'Morning', '2.0']
# ['Sensor 67357', '94028', '12/12/21 12:59:34', 'Sunday', 'Midday', '0.55']
# ['Sensor 67357', '94028', '12/12/21 18:59:38', 'Sunday', 'Evening', '0.0']
# ['Sensor 67357', '94028', '12/13/21 00:59:42', 'Monday', 'Night', '0.0']
# ['Sensor 67357', '94028', '12/13/21 06:59:46', 'Monday', 'Morning', '0.0']
# ['Sensor 67357', '94028', '12/13/21 12:59:49', 'Monday', 'Midday', '0.45']
# ['Sensor 67357', '94028', '12/13/21 18:59:53', 'Monday', 'Evening', '0.96']
# ['Sensor 67357', '94028', '12/14/21 00:59:57', 'Tuesday', 'Night', '0.42']
# ['Sensor 67357', '94028', '12/14/21 07:00:01', 'Tuesday', 'Morning', '0.12']
# ...

# %%
print(big_list)
